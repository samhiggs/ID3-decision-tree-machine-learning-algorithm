# %%
import os
import numpy as np
import pandas as pd
import importlib
import higgs

# %%
#Import data
data_fn = 'data\house-votes-84.data'
names = [
       'Class Name',
   'handicapped-infants',
   'water-project-cost-sharing',
   'adoption-of-the-budget-resolution',
   'physician-fee-freeze',
   'el-salvador-aid',
   'religious-groups-in-schools',
   'anti-satellite-test-ban',
   'aid-to-nicaraguan-contras',
  'mx-missile',
  'immigration',
  'synfuels-corporation-cutback',
  'education-spending',
  'superfund-right-to-sue',
  'crime',
  'duty-free-exports',
  'export-administration-act-south-africa',
]
names = [ name.replace(' ', '_').lower() for name in names]
data = pd.read_csv(data_fn,names=names )
data = data.replace('?', np.nan)
data = data.fillna(method='pad')
data = data.fillna('y')
n = names.pop(0)
names.append(n)
importlib.reload(higgs)
train, test = higgs.split_data(data.values, .8)
root = higgs.ID3(3,3,train, names)
# Out:
# running split_data
# ['handicapped-infants', 'water-project-cost-sharing', 'adoption-of-the-budget-resolution', 'physician-fee-freeze', 'el-salvador-aid', 'religious-groups-in-schools', 'anti-satellite-test-ban', 'aid-to-nicaraguan-contras', 'mx-missile', 'immigration', 'synfuels-corporation-cutback', 'education-spending', 'superfund-right-to-sue', 'crime', 'duty-free-exports', 'export-administration-act-south-africa', 'class_name']
#
# ******************Building Tree*******************
#
# ['handicapped-infants', 'water-project-cost-sharing', 'adoption-of-the-budget-resolution', 'physician-fee-freeze', 'el-salvador-aid', 'religious-groups-in-schools', 'anti-satellite-test-ban', 'aid-to-nicaraguan-contras', 'mx-missile', 'immigration', 'synfuels-corporation-cutback', 'education-spending', 'superfund-right-to-sue', 'crime', 'duty-free-exports', 'export-administration-act-south-africa', 'class_name'] (348, 17)
# ...

# %%
higgs.print_tree(root)
# Out:
#  Parent root : root
#  Node
#             Feature : root
#             Decision : root
#             N Children : 2
#
#    Parent root : root
#    Node
#             Feature : aid-to-nicaraguan-contras
#             Decision : n
#             N Children : 2
#
#    Parent root : root
#    Node
#             Feature : aid-to-nicaraguan-contras
#             Decision : y
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : n
#      Node
#             Feature : physician-fee-freeze
#             Decision : n
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : n
#      Node
#             Feature : physician-fee-freeze
#             Decision : y
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : y
#      Node
#             Feature : n
#             Decision : y
#             N Children : False
#
#      Parent aid-to-nicaraguan-contras : y
#      Node
#             Feature : y
#             Decision : y
# ...

# %%
data.head()
# Out:
#    class_name handicapped-infants water-project-cost-sharing  \
# 0  republican                   n                          y
# 1  republican                   n                          y
# 2    democrat                   n                          y
# 3    democrat                   n                          y
# 4    democrat                   y                          y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                    y               y
# 3                                 y                    n               y
# 4                                 y                    n               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# ...

# %%
data.describe()
# Out:
#        class_name handicapped-infants water-project-cost-sharing  \
# count         435                 435                        435
# unique          2                   2                          2
# top      democrat                   n                          n
# freq          267                 243                        223
#
#        adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# count                                435                  435             435
# unique                                 2                    2               2
# top                                    y                    n               y
# freq                                 255                  250             220
#
#        religious-groups-in-schools anti-satellite-test-ban  \
# count                          435                     435
# unique                           2                       2
# top                              y                       y
# ...

# %%
higgs.print_tree(root)
# Out:
#  Parent root : root
#  Node
#             Feature : root
#             Decision : root
#             N Children : 2
#
#    Parent root : root
#    Node
#             Feature : aid-to-nicaraguan-contras
#             Decision : n
#             N Children : 2
#
#    Parent root : root
#    Node
#             Feature : aid-to-nicaraguan-contras
#             Decision : y
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : n
#      Node
#             Feature : physician-fee-freeze
#             Decision : n
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : n
#      Node
#             Feature : physician-fee-freeze
#             Decision : y
#             N Children : 2
#
#      Parent aid-to-nicaraguan-contras : y
#      Node
#             Feature : n
#             Decision : y
#             N Children : False
#
#      Parent aid-to-nicaraguan-contras : y
#      Node
#             Feature : y
#             Decision : y
# ...
